# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Discretización de una señal

# %%
# Definir parámetros de la señal
frecuencia_original = 5  # Frecuencia original en Hz
t = np.linspace(0, 1, 1000) # vector tiempo de 0 a 1 segundo
amplitud_señal = 1 # definimos la amplitud de la señal senoidal

señal_senoidal = amplitud_señal * np.sin(2*np.pi*frecuencia_original*t) # generamos la señal senoidal

# Graficar la señal original
plt.figure(figsize=(12, 6))
plt.plot(tiempo, senal_original, label='Señal original')
plt.title('Señal original')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()
plt.show()

# Frecuencias de muestreo: 1000, 100, 25, 10, 4, 1



# Graficar las señales discretizadas
fs = 25 # frecuencia de muestreo de la señal en Hz
t = np.arange(0, 1, 1/fs) # vector tiempo de 0 a 1 segundo
senal_discreta = np.sin(2 * np.pi * frecuencia_original * t)
plt.stem(t, senal_discreta)
plt.title(f'Señal discretizada a {fs} Hz de frecuencia de muestreo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.show()
